# %% [markdown]
# # Group member

# %%
# !pip install yfinance
# Out:
# ...
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/1c/19/bf19123baf16a55fd38cbb100b5a49380b9b6db7279987034689d11254c7/yfinance-0.2.32-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#       --------------------------------------- 0.0/2.9 MB 991.0 kB/s eta 0:00:03
#      - -------------------------------------- 0.1/2.9 MB 1.7 MB/s eta 0:00:02
#      --- ------------------------------------ 0.3/2.9 MB 2.3 MB/s eta 0:00:02
#      ---- ----------------------------------- 0.3/2.9 MB 1.7 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.4/2.9 MB 2.4 MB/s eta 0:00:02
#      --------- ------------------------------ 0.7/2.9 MB 2.9 MB/s eta 0:00:01
#      --------- ------------------------------ 0.7/2.9 MB 2.9 MB/s eta 0:00:01
#      -------------- ------------------------- 1.1/2.9 MB 3.2 MB/s eta 0:00:01
# ...

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Download historical data for AAPL
ticker = "AAPL"
apple_data = yf.download(ticker, start="2023-01-01", end="2023-11-20")

# Calculate daily returns
daily_returns = apple_data['Adj Close'].pct_change()

# Calculate monthly returns
monthly_returns = daily_returns.resample('M').mean()

# Plotting bar chart for average monthly returns
monthly_returns.plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.title('Average Monthly Returns of AAPL in 2023')
plt.xlabel('Month')
plt.ylabel('Average Returns')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data = yf.download('AAPL', start='2020-01-01', end='2021-01-01')
