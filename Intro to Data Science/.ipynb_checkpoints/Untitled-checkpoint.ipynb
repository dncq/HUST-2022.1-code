# %%
# !pip install selenium
# Out:
# ...
#    ---------------------------------------- 10.2/10.2 MB 7.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 448.2/448.2 kB 5.6 MB/s eta 0:00:00
# ...

# %%
import requests                # Make HTTP requests to retrieve web pages.
from bs4 import BeautifulSoup  # Parse HTML/ XML documents
import scrapy                  # Navigate website and extract data at scale
import selenium                # Provide WebDriver to simulate users'interaction with website (click, hover, press, ...)

import time
import datetime
import smtplib

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Connect to website
URL = "https://cellphones.com.vn/laptop-msi-gaming-gf63-12ve-460vn.html"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers = headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id= "producttitle").get_text()
